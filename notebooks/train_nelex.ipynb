# %%
from collections import defaultdict
import itertools
from pathlib import Path
import torch
from torch.nn import CrossEntropyLoss
from torch.optim import Adam 
from torch.utils.data import DataLoader

from eff.data import get_word_list
from eff.data.dataset import CLTSDataset
from eff.model import lstm
from eff.train import get_class_weights_balanced, get_train_test_valid_split, generate_batch
from eff.train.dataset import TrainDataset, UnmaskedTestSet, \
    ConsonantMaskingTestSet, VowelMaskingTestSet
from eff.train.scripts import train, test
from eff.util import constants
from eff.util.util import save_results

torch.manual_seed(0)
torch.cuda.manual_seed(0)
import numpy as np
# np.random.seed(0)
base_path = Path("./out/nelex_unique")

# %%
word_list = get_word_list('northeuralex')
# Out:
# loading forms for northeuralex: 100%|██████████| 121612/121612 [00:02<00:00, 42773.28it/s]

# %%
batch_size = 32
n_layers = 2
embedding_size = 32
hidden_size = 256
dropout = 0.33
patience = 2

# %%
# lang_ids_dev = ['fin', 'tur', 'mnc', 'hun', 'khk', 'arb', 'ain', 'ekk', 'hye', 'eus']
# languages = [
#     lang for lang in word_list.languages
#     if lang.id.split("-")[1] in lang_ids_dev
# ]
# print(len(languages))

languages = word_list.languages

# %%
for language in languages:
    print(language.name)
    datasets = defaultdict(lambda: defaultdict(lambda: {}))
    res = defaultdict(lambda: defaultdict(lambda: {}))    
    lang_id = language.id.split("-")[1]
    clts_dataset = CLTSDataset(language.forms, unique_sequences=True)
    datasets['clts'] = clts_dataset

    train_words, valid_words, test_words = get_train_test_valid_split(clts_dataset.words, \
        test_size=0.3, valid_size=0.1)
    print("N= {}".format(len(test_words)))

    train_set = TrainDataset(
                    words=train_words,
                    input_alphabet=clts_dataset.input_alphabet,
                    output_alphabet=clts_dataset.output_alphabet,
                    bipa=clts_dataset.bipa,
                    masking=0.25
                )
    valid_set = TrainDataset( 
                    words=valid_words,
                    input_alphabet=clts_dataset.input_alphabet,
                    output_alphabet=clts_dataset.output_alphabet,
                    bipa=clts_dataset.bipa, 
                    masking=0.25
                )
    test_set = UnmaskedTestSet(
                    words=test_words,
                    input_alphabet=clts_dataset.input_alphabet,
                    output_alphabet=clts_dataset.output_alphabet,
                    bipa=clts_dataset.bipa
                )
    test_set_vowel = VowelMaskingTestSet(
                        words=test_words,
                        input_alphabet=clts_dataset.input_alphabet,
                        output_alphabet=clts_dataset.output_alphabet,
                        bipa=clts_dataset.bipa
                    )

    test_set_consonant = ConsonantMaskingTestSet(
                            words=test_words,
                            input_alphabet=clts_dataset.input_alphabet,
                            output_alphabet=clts_dataset.output_alphabet,
                            bipa=clts_dataset.bipa
                        )

    datasets['torch']['unmasked'] = test_set
    datasets['torch']['vowel_masking'] = test_set_vowel
    datasets['torch']['consonant_masking'] = test_set_consonant

    train_loader = DataLoader(train_set, batch_size=batch_size, collate_fn=generate_batch)
    valid_loader = DataLoader(valid_set, batch_size=batch_size, collate_fn=generate_batch)
    test_loader = DataLoader(test_set, batch_size=batch_size, collate_fn=generate_batch)
    test_loader_vowel = DataLoader(test_set_vowel, batch_size=batch_size, collate_fn=generate_batch)
    test_loader_consonant = DataLoader(test_set_consonant, batch_size=batch_size, collate_fn=generate_batch)
    
    train_labels = list(itertools.chain.from_iterable([t.cpu().tolist() for t in train_set._Y]))  
    
    missing_labels = list(set(clts_dataset.output_alphabet.indices).difference(set(train_labels)))
    train_labels = train_labels + [clts_dataset.output_alphabet.PAD_IDX] + missing_labels
    weight = get_class_weights_balanced(ignore_classes=[clts_dataset.pad_idx, clts_dataset.mask_idx], \
        classes=clts_dataset.output_alphabet.indices, y=train_labels)

    criterion = CrossEntropyLoss(weight=weight)
    model = lstm.LstmLM(
        input_dim=len(clts_dataset.input_alphabet),
        output_dim=len(clts_dataset.output_alphabet),
        embedding_dim=embedding_size,
        hidden_dim=hidden_size,
        dropout=dropout,
        n_layers=n_layers,
        loss_fn=criterion
    )
    # print(model)
    model.to(constants.device)
    optimizer = Adam(model.parameters())
    
    train(model, train_loader, valid_loader, optimizer, criterion, patience=patience)

    logprobs, target_indices, targets = test(model, test_loader, criterion)
    res['unmasked']['logprobs'] = logprobs
    res['unmasked']['targets'] = targets
    res['unmasked']['indices'] = target_indices
    
    logprobs, target_indices, targets = test(model, test_loader_vowel, criterion)
    res['vowel_masking']['logprobs'] = logprobs
    res['vowel_masking']['targets'] = targets
    res['vowel_masking']['indices'] = target_indices

    logprobs, target_indices, targets = test(model, test_loader_consonant, criterion)
    res['consonant_masking']['logprobs'] = logprobs
    res['consonant_masking']['targets'] = targets
    res['consonant_masking']['indices'] = target_indices

    model.to('cpu')
    criterion.to('cpu')

    save_results(base_path, lang_id, datasets, res, criterion, model)

# Hungarian
# N= 234
# Epoch	Loss	Perplexity
# 1	0.0816	0	
# 2	0.0786	0	
# 3	0.0772	0	
# 4	0.0744	0	
# 5	0.0755	0	
# Best epoch: 4, best valid loss: 0.07
# Test loss: 0.07218802484691653
# Test perplexity: 0
# Test loss: 0.06732728052590548
# Test perplexity: 0
# Test loss: 0.07600941311599863
# Test perplexity: 0
# Out:
# Finnish
# N= 265
# Epoch	Loss	Perplexity
# 1	0.097	0
# 2	0.09	0
# 3	0.089	0
# 4	0.0882	0
# 5	0.0875	0
# 6	0.0881	0
# Best epoch: 5, best valid loss: 0.09
# Test loss: 0.10789355421965977
# Test perplexity: 0
# Test loss: 0.09135610133677989
# Test perplexity: 0
# Test loss: 0.10945389225797833
# Test perplexity: 0
# North Karelian
# N= 302
# Epoch	Loss	Perplexity
# 1	0.1068	0
# 2	0.1027	0
# 3	0.0976	0
# 4	0.0959	0
# 5	0.0956	0
# 6	0.0947	0
# 7	0.0934	0
# 8	0.0922	0
# 9	0.0919	0
# 10	0.0939	0
# Best epoch: 9, best valid loss: 0.09
# Test loss: 0.07305502812593978
# Test perplexity: 0
# Test loss: 0.06679235273156284
# Test perplexity: 0
# Test loss: 0.07582287598919395
# Test perplexity: 0
# Olonets Karelian
# N= 326
# Epoch	Loss	Perplexity
# 1	0.1083	0
# 2	0.1088	0
# Best epoch: 1, best valid loss: 0.11
# Test loss: 0.0872304066558557
# Test perplexity: 0
# Test loss: 0.07528810029806093
# Test perplexity: 0
# Test loss: 0.08725657492327543
# Test perplexity: 0
# Veps
# N= 219
# Epoch	Loss	Perplexity
# 1	0.0954	0
# 2	0.0906	0
# 3	0.0859	0
# 4	0.0846	0
# 5	0.0843	0
# 6	0.0841	0
# 7	0.0819	0
# 8	0.0827	0
# Best epoch: 7, best valid loss: 0.08
# Test loss: 0.08475428084804587
# Test perplexity: 0
# Test loss: 0.0613275738505574
# Test perplexity: 0
# Test loss: 0.09059029082729392
# Test perplexity: 0
# Estonian
# N= 234
# Epoch	Loss	Perplexity
# 1	0.0889	0
# 2	0.0825	0
# 3	0.0794	0
# 4	0.0791	0
# 5	0.0792	0
# Best epoch: 4, best valid loss: 0.08
# Test loss: 0.08965196161188631
# Test perplexity: 0
# Test loss: 0.07073551678972623
# Test perplexity: 0
# Test loss: 0.08961990755847377
# Test perplexity: 0
# Livonian
# N= 235
# Epoch	Loss	Perplexity
# 1	0.12	0
# 2	0.1584	0
# Best epoch: 1, best valid loss: 0.12
# Test loss: 0.09135623789848166
# Test perplexity: 0
# Test loss: 0.07656771704427918
# Test perplexity: 0
# Test loss: 0.09115741202171812
# Test perplexity: 0
# Southern Sami
# N= 300
# Epoch	Loss	Perplexity
# 1	0.1183	0
# 2	0.1068	0
# 3	0.0987	0
# 4	0.0938	0
# 5	0.0903	0
# 6	0.0887	0
# 7	0.0887	0
# Best epoch: 6, best valid loss: 0.09
# Test loss: 0.083021742105484
# Test perplexity: 0
# Test loss: 0.08049240350723266
# Test perplexity: 0
# Test loss: 0.08769885619481405
# Test perplexity: 0
# Lule Sami
# N= 264
# Epoch	Loss	Perplexity
# 1	0.0764	0
# 2	0.0681	0
# 3	0.0657	0
# 4	0.0641	0
# 5	0.0627	0
# 6	0.062	0
# 7	0.0618	0
# 8	0.0619	0
# Best epoch: 7, best valid loss: 0.06
# Test loss: 0.060570251761060775
# Test perplexity: 0
# Test loss: 0.0626030026752258
# Test perplexity: 0
# Test loss: 0.06951675360853021
# Test perplexity: 0
# Northern Sami
# N= 244
# Epoch	Loss	Perplexity
# 1	0.0937	0
# 2	0.0869	0
# 3	0.079	0
# 4	0.0736	0
# 5	0.0689	0
# 6	0.0652	0
# 7	0.0632	0
# 8	0.0622	0
# 9	0.0578	0
# 10	0.0634	0
# Best epoch: 9, best valid loss: 0.06
# Test loss: 0.10488681031055137
# Test perplexity: 0
# Test loss: 0.07208300399048553
# Test perplexity: 0
# Test loss: 0.10828688398736422
# Test perplexity: 0
# Inari Sami
# N= 258
# Epoch	Loss	Perplexity
# 1	0.0882	0
# 2	0.0819	0
# 3	0.0761	0
# 4	0.0702	0
# 5	0.0685	0
# 6	0.0654	0
# 7	0.0675	0
# Best epoch: 6, best valid loss: 0.07
# Test loss: 0.08174928121788558
# Test perplexity: 0
# Test loss: 0.0676822487596442
# Test perplexity: 0
# Test loss: 0.08330065150593602
# Test perplexity: 0
# Skolt Sami
# N= 266
# Epoch	Loss	Perplexity
# 1	0.0901	0
# 2	0.087	0
# 3	0.0839	0
# 4	0.0807	0
# 5	0.0799	0
# 6	0.0796	0
# 7	0.0777	0
# 8	0.0786	0
# Best epoch: 7, best valid loss: 0.08
# Test loss: 0.17154630144735925
# Test perplexity: 0
# Test loss: 0.18559577029797297
# Test perplexity: 0
# Test loss: 0.17772746623906874
# Test perplexity: 0
# Kildin Sami
# N= 181
# Epoch	Loss	Perplexity
# 1	0.1159	0
# 2	0.153	0
# Best epoch: 1, best valid loss: 0.12
# Test loss: 0.07536521537527853
# Test perplexity: 0
# Test loss: 0.06622960525829198
# Test perplexity: 0
# Test loss: 0.07338131462012865
# Test perplexity: 0
# Hill Mari
# N= 252
# Epoch	Loss	Perplexity
# 1	0.0897	0
# 2	0.0844	0
# 3	0.0807	0
# 4	0.0777	0
# 5	0.0776	0
# 6	0.0775	0
# 7	0.0767	0
# 8	0.0773	0
# Best epoch: 7, best valid loss: 0.08
# Test loss: 0.0655980214240059
# Test perplexity: 0
# Test loss: 0.0632670678257626
# Test perplexity: 0
# Test loss: 0.0732461583046686
# Test perplexity: 0
# Meadow Mari
# N= 251
# Epoch	Loss	Perplexity
# 1	0.0685	0
# 2	0.0653	0
# 3	0.0636	0
# 4	0.0623	0
# 5	0.0611	0
# 6	0.0602	0
# 7	0.0594	0
# 8	0.0596	0
# Best epoch: 7, best valid loss: 0.06
# Test loss: 0.055952133410480394
# Test perplexity: 0
# Test loss: 0.0544123652993444
# Test perplexity: 0
# Test loss: 0.06785251324870196
# Test perplexity: 0
# Moksha
# N= 236
# Epoch	Loss	Perplexity
# 1	0.0968	0
# 2	0.0937	0
# 3	0.0954	0
# Best epoch: 2, best valid loss: 0.09
# Test loss: 0.06456151655164816
# Test perplexity: 0
# Test loss: 0.05210061272557943
# Test perplexity: 0
# Test loss: 0.0659302887270006
# Test perplexity: 0
# Erzya
# N= 234
# Epoch	Loss	Perplexity
# 1	0.0726	0
# 2	0.0675	0
# 3	0.0628	0
# 4	0.0601	0
# 5	0.0577	0
# 6	0.0626	0
# Best epoch: 5, best valid loss: 0.06
# Test loss: 0.05967080491220849
# Test perplexity: 0
# Test loss: 0.053746454957602684
# Test perplexity: 0
# Test loss: 0.0639010341758402
# Test perplexity: 0
# Udmurt
# N= 229
# Epoch	Loss	Perplexity
# 1	0.072	0
# 2	0.0658	0
# 3	0.0633	0
# 4	0.0615	0
# 5	0.0607	0
# 6	0.0613	0
# Best epoch: 5, best valid loss: 0.06
# Test loss: 0.06300234898729616
# Test perplexity: 0
# Test loss: 0.052459383943553074
# Test perplexity: 0
# Test loss: 0.06566427732659219
# Test perplexity: 0
# Komi-Permyak
# N= 209
# Epoch	Loss	Perplexity
# 1	0.0785	0
# 2	0.0722	0
# 3	0.0712	0
# 4	0.0697	0
# 5	0.0684	0
# 6	0.0672	0
# 7	0.0662	0
# 8	0.0655	0
# 9	0.0657	0
# Best epoch: 8, best valid loss: 0.07
# Test loss: 0.05160464225203227
# Test perplexity: 0
# Test loss: 0.04726519017684751
# Test perplexity: 0
# Test loss: 0.06777409959637948
# Test perplexity: 0
# Komi-Zyrian
# N= 222
# Epoch	Loss	Perplexity
# 1	0.0785	0
# 2	0.0725	0
# 3	0.0717	0
# 4	0.0717	0
# Best epoch: 3, best valid loss: 0.07
# Test loss: 0.06271613771850998
# Test perplexity: 0
# Test loss: 0.04984904862940311
# Test perplexity: 0
# Test loss: 0.06301979438678638
# Test perplexity: 0
# Hungarian
# N= 234
# Epoch	Loss	Perplexity
# 1	0.0816	0
# 2	0.0783	0
# 3	0.0751	0
# 4	0.0741	0
# 5	0.0723	0
# 6	0.0716	0
# 7	0.0711	0
# 8	0.0704	0
# 9	0.0703	0
# 10	0.0695	0
# 11	0.0693	0
# 12	0.0697	0
# Best epoch: 11, best valid loss: 0.07
# Test loss: 0.07459209107945108
# Test perplexity: 0
# Test loss: 0.07461234748551522
# Test perplexity: 0
# Test loss: 0.0841515431037316
# Test perplexity: 0
# Northern Khanty
# N= 199
# Epoch	Loss	Perplexity
# 1	0.0862	0
# 2	0.0767	0
# 3	0.0737	0
# 4	0.0711	0
# 5	0.0697	0
# 6	0.0685	0
# 7	0.0675	0
# 8	0.0663	0
# 9	0.0676	0
# Best epoch: 8, best valid loss: 0.07
# Test loss: 0.05437087174036994
# Test perplexity: 0
# Test loss: 0.04681644239866665
# Test perplexity: 0
# Test loss: 0.06668907074473011
# Test perplexity: 0
# Northern Mansi
# N= 231
# Epoch	Loss	Perplexity
# 1	0.0771	0
# 2	0.0714	0
# 3	0.0641	0
# 4	0.0608	0
# 5	0.0587	0
# 6	0.057	0
# 7	0.0571	0
# Best epoch: 6, best valid loss: 0.06
# Test loss: 0.06424407731919062
# Test perplexity: 0
# Test loss: 0.04953656691810559
# Test perplexity: 0
# Test loss: 0.08427959809571633
# Test perplexity: 0
# Northern Selkup
# N= 227
# Epoch	Loss	Perplexity
# 1	0.0866	0
# 2	0.0805	0
# 3	0.0768	0
# 4	0.0747	0
# 5	0.0721	0
# 6	0.0705	0
# 7	0.0686	0
# 8	0.0675	0
# 9	0.0678	0
# Best epoch: 8, best valid loss: 0.07
# Test loss: 0.06228503834308507
# Test perplexity: 0
# Test loss: 0.058379326938489164
# Test perplexity: 0
# Test loss: 0.07888108833245769
# Test perplexity: 0
# Tundra Nenets
# N= 243
# Epoch	Loss	Perplexity
# 1	0.0796	0
# 2	0.0746	0
# 3	0.0743	0
# 4	0.0749	0
# Best epoch: 3, best valid loss: 0.07
# Test loss: 0.06856492124957803
# Test perplexity: 0
# Test loss: 0.06495947052792805
# Test perplexity: 0
# Test loss: 0.07505962681868439
# Test perplexity: 0
# Forest Enets
# N= 200
# Epoch	Loss	Perplexity
# 1	0.0986	0
# 2	0.0877	0
# 3	0.079	0
# 4	0.0753	0
# 5	0.0748	0
# 6	0.0752	0
# Best epoch: 5, best valid loss: 0.07
# Test loss: 0.0830964595079422
# Test perplexity: 0
# Test loss: 0.0600775584839938
# Test perplexity: 0
# Test loss: 0.08894123375415802
# Test perplexity: 0
# Nganasan
# N= 271
# Epoch	Loss	Perplexity
# 1	0.0795	0
# 2	0.0759	0
# 3	0.0712	0
# 4	0.0689	0
# 5	0.0671	0
# 6	0.0658	0
# 7	0.0659	0
# Best epoch: 6, best valid loss: 0.07
# Test loss: 0.07462146229409644
# Test perplexity: 0
# Test loss: 0.0739960658530361
# Test perplexity: 0
# Test loss: 0.08407167886895887
# Test perplexity: 0
# Bengali
# N= 229
# Epoch	Loss	Perplexity
# 1	0.1218	0
# 2	0.129	0
# Best epoch: 1, best valid loss: 0.12
# Test loss: 0.11516343141747354
# Test perplexity: 0
# Test loss: 0.10234037206865468
# Test perplexity: 0
# Test loss: 0.11731764322805613
# Test perplexity: 0
# Hindi
# N= 303
# Epoch	Loss	Perplexity
# 1	0.1252	0
# 2	0.1271	0
# Best epoch: 1, best valid loss: 0.13
# Test loss: 0.09870878619329371
# Test perplexity: 0
# Test loss: 0.0863149642944336
# Test perplexity: 0
# Test loss: 0.09897372667545533
# Test perplexity: 0
# Northern Pashto
# N= 245
# Epoch	Loss	Perplexity
# 1	0.102	0
# 2	0.1209	0
# Best epoch: 1, best valid loss: 0.1
# Test loss: 0.07390361124155473
# Test perplexity: 0
# Test loss: 0.06451908001707173
# Test perplexity: 0
# Test loss: 0.07598070709072814
# Test perplexity: 0
# Western Farsi
# N= 247
# Epoch	Loss	Perplexity
# 1	0.0668	0
# 2	0.0649	0
# 3	0.0621	0
# 4	0.06	0
# 5	0.0599	0
# 6	0.058	0
# 7	0.0583	0
# Best epoch: 6, best valid loss: 0.06
# Test loss: 0.06276411517911594
# Test perplexity: 0
# Test loss: 0.051849712788219184
# Test perplexity: 0
# Test loss: 0.06632053128138245
# Test perplexity: 0
# Northern Kurdish
# N= 218
# Epoch	Loss	Perplexity
# 1	0.0855	0
# 2	0.0813	0
# 3	0.0786	0
# 4	0.0776	0
# 5	0.0779	0
# Best epoch: 4, best valid loss: 0.08
# Test loss: 0.063154364944598
# Test perplexity: 0
# Test loss: 0.06085977634461988
# Test perplexity: 0
# Test loss: 0.06985867570299621
# Test perplexity: 0
# Ossetian
# N= 264
# Epoch	Loss	Perplexity
# 1	0.0787	0
# 2	0.0718	0
# 3	0.0737	0
# Best epoch: 2, best valid loss: 0.07
# Test loss: 0.0820130209128062
# Test perplexity: 0
# Test loss: 0.07422127595511815
# Test perplexity: 0
# Test loss: 0.08330060496474757
# Test perplexity: 0
# Armenian
# N= 233
# Epoch	Loss	Perplexity
# 1	0.0774	0
# 2	0.0722	0
# 3	0.0708	0
# 4	0.069	0
# 5	0.0683	0
# 6	0.0677	0
# 7	0.0677	0
# Best epoch: 6, best valid loss: 0.07
# Test loss: 0.06266065268045842
# Test perplexity: 0
# Test loss: 0.06369369133941484
# Test perplexity: 0
# Test loss: 0.06991443153103022
# Test perplexity: 0
# Modern Greek
# N= 289
# Epoch	Loss	Perplexity
# 1	0.0803	0
# 2	0.0765	0
# 3	0.074	0
# 4	0.0741	0
# Best epoch: 3, best valid loss: 0.07
# Test loss: 0.06385342225071468
# Test perplexity: 0
# Test loss: 0.05828131995069871
# Test perplexity: 0
# Test loss: 0.07243172190181112
# Test perplexity: 0
# Standard Albanian
# N= 228
# Epoch	Loss	Perplexity
# 1	0.0731	0
# 2	0.0695	0
# 3	0.0682	0
# 4	0.0681	0
# 5	0.0683	0
# Best epoch: 4, best valid loss: 0.07
# Test loss: 0.08550276986339636
# Test perplexity: 0
# Test loss: 0.07819188840977558
# Test perplexity: 0
# Test loss: 0.09420057033237658
# Test perplexity: 0
# Bulgarian
# N= 272
# Epoch	Loss	Perplexity
# 1	0.1016	0
# 2	0.1262	0
# Best epoch: 1, best valid loss: 0.1
# Test loss: 0.07417905374484904
# Test perplexity: 0
# Test loss: 0.06537238914187592
# Test perplexity: 0
# Test loss: 0.07749464406686671
# Test perplexity: 0
# Croatian
# N= 295
# Epoch	Loss	Perplexity
# 1	0.07	0
# 2	0.0643	0
# 3	0.0616	0
# 4	0.0585	0
# 5	0.0557	0
# 6	0.0545	0
# 7	0.0532	0
# 8	0.0528	0
# 9	0.0511	0
# 10	0.0505	0
# 11	0.0498	0
# 12	0.0499	0
# Best epoch: 11, best valid loss: 0.05
# Test loss: 0.04346090494576147
# Test perplexity: 0
# Test loss: 0.03753126900381562
# Test perplexity: 0
# Test loss: 0.05129237700316865
# Test perplexity: 0
# Slovene
# N= 255
# Epoch	Loss	Perplexity
# 1	0.0748	0
# 2	0.0657	0
# 3	0.0632	0
# 4	0.0635	0
# Best epoch: 3, best valid loss: 0.06
# Test loss: 0.0747411237043493
# Test perplexity: 0
# Test loss: 0.06123654292598707
# Test perplexity: 0
# Test loss: 0.07817487623177323
# Test perplexity: 0
# Slovak
# N= 241
# Epoch	Loss	Perplexity
# 1	0.0782	0
# 2	0.0734	0
# 3	0.0703	0
# 4	0.0669	0
# 5	0.0668	0
# 6	0.0634	0
# 7	0.0644	0
# Best epoch: 6, best valid loss: 0.06
# Test loss: 0.07182518773059132
# Test perplexity: 0
# Test loss: 0.0685341631950334
# Test perplexity: 0
# Test loss: 0.08174980329774723
# Test perplexity: 0
# Czech
# N= 240
# Epoch	Loss	Perplexity
# 1	0.0725	0
# 2	0.0681	0
# 3	0.0665	0
# 4	0.0646	0
# 5	0.0648	0
# Best epoch: 4, best valid loss: 0.06
# Test loss: 0.07463509738445281
# Test perplexity: 0
# Test loss: 0.06044684568556344
# Test perplexity: 0
# Test loss: 0.07953222642342249
# Test perplexity: 0
# Polish
# N= 256
# Epoch	Loss	Perplexity
# 1	0.1043	0
# 2	0.113	0
# Best epoch: 1, best valid loss: 0.1
# Test loss: 0.07429851684719324
# Test perplexity: 0
# Test loss: 0.07111228379336271
# Test perplexity: 0
# Test loss: 0.07949319761246443
# Test perplexity: 0
# Ukrainian
# N= 273
# Epoch	Loss	Perplexity
# 1	0.0576	0
# 2	0.0538	0
# 3	0.0519	0
# 4	0.0499	0
# 5	0.0478	0
# 6	0.0469	0
# 7	0.0454	0
# 8	0.0443	0
# 9	0.0433	0
# 10	0.0433	0
# Best epoch: 9, best valid loss: 0.04
# Test loss: 0.0436678137971368
# Test perplexity: 0
# Test loss: 0.042796414260309106
# Test perplexity: 0
# Test loss: 0.05876266694330907
# Test perplexity: 0
# Belarusian
# N= 266
# Epoch	Loss	Perplexity
# 1	0.0607	0
# 2	0.0561	0
# 3	0.0545	0
# 4	0.0522	0
# 5	0.0499	0
# 6	0.0484	0
# 7	0.0478	0
# 8	0.0469	0
# 9	0.0467	0
# 10	0.0461	0
# 11	0.0464	0
# Best epoch: 10, best valid loss: 0.05
# Test loss: 0.04858305803815225
# Test perplexity: 0
# Test loss: 0.047211559613545735
# Test perplexity: 0
# Test loss: 0.07749939233736884
# Test perplexity: 0
# Russian
# N= 252
# Epoch	Loss	Perplexity
# 1	0.0839	0
# 2	0.0755	0
# 3	0.0721	0
# 4	0.0695	0
# 5	0.0662	0
# 6	0.0641	0
# 7	0.0622	0
# 8	0.0574	0
# 9	0.054	0
# 10	0.0522	0
# 11	0.0514	0
# 12	0.0502	0
# 13	0.0482	0
# 14	0.0503	0
# Best epoch: 13, best valid loss: 0.05
# Test loss: 0.05603423383500841
# Test perplexity: 0
# Test loss: 0.06348637352144815
# Test perplexity: 0
# Test loss: 0.08747086165443299
# Test perplexity: 0
# Lithuanian
# N= 324
# Epoch	Loss	Perplexity
# 1	0.1169	0
# 2	0.1155	0
# 3	0.116	0
# Best epoch: 2, best valid loss: 0.12
# Test loss: 0.09770547239868729
# Test perplexity: 0
# Test loss: 0.08539115929406536
# Test perplexity: 0
# Test loss: 0.10037996224415155
# Test perplexity: 0
# Latvian
# N= 175
# Epoch	Loss	Perplexity
# 1	0.1197	0
# 2	0.115	0
# 3	0.1122	0
# 4	0.1104	0
# 5	0.1101	0
# 6	0.1104	0
# Best epoch: 5, best valid loss: 0.11
# Test loss: 0.07976319721766881
# Test perplexity: 0
# Test loss: 0.07011876753934725
# Test perplexity: 0
# Test loss: 0.08300979069301061
# Test perplexity: 0
# Icelandic
# N= 231
# Epoch	Loss	Perplexity
# 1	0.1048	0
# 2	0.1046	0
# 3	0.1041	0
# 4	0.1013	0
# 5	0.1073	0
# Best epoch: 4, best valid loss: 0.1
# Test loss: 0.08055310073869053
# Test perplexity: 0
# Test loss: 0.0864374385939704
# Test perplexity: 0
# Test loss: 0.08166768334128639
# Test perplexity: 0
# Norwegian (Bokmål)
# N= 191
# Epoch	Loss	Perplexity
# 1	0.138	0
# 2	0.1352	0
# 3	0.1334	0
# 4	0.1295	0
# 5	0.1351	0
# Best epoch: 4, best valid loss: 0.13
# Test loss: 0.09425298331295633
# Test perplexity: 0
# Test loss: 0.09772260122031093
# Test perplexity: 0
# Test loss: 0.09747541512494312
# Test perplexity: 0
# Swedish
# N= 206
# Epoch	Loss	Perplexity
# 1	0.1219	0
# 2	0.1204	0
# 3	0.1167	0
# 4	0.1136	0
# 5	0.1112	0
# 6	0.1108	0
# 7	0.1108	0
# Best epoch: 6, best valid loss: 0.11
# Test loss: 0.09163185577948117
# Test perplexity: 0
# Test loss: 0.08539086930892047
# Test perplexity: 0
# Test loss: 0.0986269226351988
# Test perplexity: 0
# Danish
# N= 183
# Epoch	Loss	Perplexity
# 1	0.149	0
# 2	0.1385	0
# 3	0.1337	0
# 4	0.1284	0
# 5	0.1299	0
# Best epoch: 4, best valid loss: 0.13
# Test loss: 0.11527082177459216
# Test perplexity: 0
# Test loss: 0.09606111628806543
# Test perplexity: 0
# Test loss: 0.11532364256395017
# Test perplexity: 0
# German
# N= 171
# Epoch	Loss	Perplexity
# 1	0.1679	0
# 2	0.2455	0
# Best epoch: 1, best valid loss: 0.17
# Test loss: 0.11130192684151276
# Test perplexity: 0
# Test loss: 0.10871445039474287
# Test perplexity: 0
# Test loss: 0.11082296343574748
# Test perplexity: 0
# Dutch
# N= 181
# Epoch	Loss	Perplexity
# 1	0.1562	0
# 2	0.1737	0
# Best epoch: 1, best valid loss: 0.16
# Test loss: 0.10702350389891567
# Test perplexity: 0
# Test loss: 0.108163442221111
# Test perplexity: 0
# Test loss: 0.10645760488773577
# Test perplexity: 0
# English
# N= 153
# Epoch	Loss	Perplexity
# 1	0.1505	0
# 2	0.1399	0
# 3	0.1376	0
# 4	0.1349	0
# 5	0.1299	0
# 6	0.1255	0
# 7	0.1256	0
# Best epoch: 6, best valid loss: 0.13
# Test loss: 0.083328691183352
# Test perplexity: 0
# Test loss: 0.088277636222469
# Test perplexity: 0
# Test loss: 0.08490611057655484
# Test perplexity: 0
# Irish
# N= 217
# Epoch	Loss	Perplexity
# 1	0.0937	0
# 2	0.0871	0
# 3	0.0837	0
# 4	0.0821	0
# 5	0.0819	0
# 6	0.0805	0
# 7	0.0798	0
# 8	0.081	0
# Best epoch: 7, best valid loss: 0.08
# Test loss: 0.06944945770474623
# Test perplexity: 0
# Test loss: 0.0704207304503103
# Test perplexity: 0
# Test loss: 0.08056448022341399
# Test perplexity: 0
# Welsh
# N= 171
# Epoch	Loss	Perplexity
# 1	0.1528	0
# 2	0.1551	0
# Best epoch: 1, best valid loss: 0.15
# Test loss: 0.10539594170642876
# Test perplexity: 0
# Test loss: 0.10085087992110342
# Test perplexity: 0
# Test loss: 0.10550376825165331
# Test perplexity: 0
# Breton
# N= 181
# Epoch	Loss	Perplexity
# 1	0.1509	0
# 2	0.1378	0
# 3	0.1188	0
# 4	0.1026	0
# 5	0.0994	0
# 6	0.1073	0
# Best epoch: 5, best valid loss: 0.1
# Test loss: 0.12411677639787369
# Test perplexity: 0
# Test loss: 0.11753220113964588
# Test perplexity: 0
# Test loss: 0.12911129129525706
# Test perplexity: 0
# Latin
# N= 262
# Epoch	Loss	Perplexity
# 1	0.1147	0
# 2	0.1511	0
# Best epoch: 1, best valid loss: 0.11
# Test loss: 0.11004227536325237
# Test perplexity: 0
# Test loss: 0.09873142367915104
# Test perplexity: 0
# Test loss: 0.10997727536063158
# Test perplexity: 0
# French
# N= 224
# Epoch	Loss	Perplexity
# 1	0.1056	0
# 2	0.1028	0
# 3	0.1004	0
# 4	0.0997	0
# 5	0.1002	0
# Best epoch: 4, best valid loss: 0.1
# Test loss: 0.08618399500846863
# Test perplexity: 0
# Test loss: 0.09314200291381075
# Test perplexity: 0
# Test loss: 0.0891389399766922
# Test perplexity: 0
# Catalan
# N= 247
# Epoch	Loss	Perplexity
# 1	0.0749	0
# 2	0.0706	0
# 3	0.0679	0
# 4	0.066	0
# 5	0.0655	0
# 6	0.0649	0
# 7	0.0627	0
# 8	0.062	0
# 9	0.0618	0
# 10	0.0602	0
# 11	0.06	0
# 12	0.0579	0
# 13	0.0586	0
# Best epoch: 12, best valid loss: 0.06
# Test loss: 0.06963163107512933
# Test perplexity: 0
# Test loss: 0.07453577125013755
# Test perplexity: 0
# Test loss: 0.08477060997534377
# Test perplexity: 0
# Spanish
# N= 295
# Epoch	Loss	Perplexity
# 1	0.1037	0
# 2	0.1185	0
# Best epoch: 1, best valid loss: 0.1
# Test loss: 0.07694313566563493
# Test perplexity: 0
# Test loss: 0.0646133858286692
# Test perplexity: 0
# Test loss: 0.07793723930746822
# Test perplexity: 0
# Portuguese
# N= 309
# Epoch	Loss	Perplexity
# 1	0.1171	0
# 2	0.1118	0
# 3	0.1088	0
# 4	0.1078	0
# 5	0.1076	0
# 6	0.1063	0
# 7	0.1053	0
# 8	0.1054	0
# Best epoch: 7, best valid loss: 0.11
# Test loss: 0.14397923383126368
# Test perplexity: 0
# Test loss: 0.12502842875360284
# Test perplexity: 0
# Test loss: 0.14025655533503562
# Test perplexity: 0
# Italian
# N= 326
# Epoch	Loss	Perplexity
# 1	0.0872	0
# 2	0.0848	0
# 3	0.0817	0
# 4	0.0811	0
# 5	0.0798	0
# 6	0.0784	0
# 7	0.0792	0
# Best epoch: 6, best valid loss: 0.08
# Test loss: 0.09022215575528292
# Test perplexity: 0
# Test loss: 0.05344781921324828
# Test perplexity: 0
# Test loss: 0.0992383649744139
# Test perplexity: 0
# Romanian
# N= 259
# Epoch	Loss	Perplexity
# 1	0.0783	0
# 2	0.0723	0
# 3	0.0714	0
# 4	0.07	0
# 5	0.0688	0
# 6	0.0679	0
# 7	0.0659	0
# 8	0.066	0
# Best epoch: 7, best valid loss: 0.07
# Test loss: 0.08114097477386356
# Test perplexity: 0
# Test loss: 0.07717774029171795
# Test perplexity: 0
# Test loss: 0.08612070120439566
# Test perplexity: 0
# Turkish
# N= 274
# Epoch	Loss	Perplexity
# 1	0.0698	0
# 2	0.0653	0
# 3	0.0622	0
# 4	0.0581	0
# 5	0.0568	0
# 6	0.057	0
# Best epoch: 5, best valid loss: 0.06
# Test loss: 0.055995510442413556
# Test perplexity: 0
# Test loss: 0.05512436420198471
# Test perplexity: 0
# Test loss: 0.05762830920463061
# Test perplexity: 0
# North Azerbaijani
# N= 250
# Epoch	Loss	Perplexity
# 1	0.0735	0
# 2	0.0675	0
# 3	0.067	0
# 4	0.0636	0
# 5	0.062	0
# 6	0.0608	0
# 7	0.0591	0
# 8	0.0571	0
# 9	0.0571	0
# Best epoch: 8, best valid loss: 0.06
# Test loss: 0.053199522495269776
# Test perplexity: 0
# Test loss: 0.06452666195381225
# Test perplexity: 0
# Test loss: 0.06412064409255981
# Test perplexity: 0
# Northern Uzbek
# N= 239
# Epoch	Loss	Perplexity
# 1	0.0723	0
# 2	0.0668	0
# 3	0.0613	0
# 4	0.0566	0
# 5	0.0529	0
# 6	0.0513	0
# 7	0.0514	0
# Best epoch: 6, best valid loss: 0.05
# Test loss: 0.05130216716223681
# Test perplexity: 0
# Test loss: 0.043391892075867036
# Test perplexity: 0
# Test loss: 0.05772591983922855
# Test perplexity: 0
# Kazakh
# N= 305
# Epoch	Loss	Perplexity
# 1	0.0989	0
# 2	0.0949	0
# 3	0.0919	0
# 4	0.0917	0
# 5	0.0893	0
# 6	0.0882	0
# 7	0.0876	0
# 8	0.087	0
# 9	0.0852	0
# 10	0.0847	0
# 11	0.0842	0
# 12	0.0832	0
# 13	0.083	0
# 14	0.0829	0
# 15	0.0832	0
# Best epoch: 14, best valid loss: 0.08
# Test loss: 0.06957741330881588
# Test perplexity: 0
# Test loss: 0.06520896477806837
# Test perplexity: 0
# Test loss: 0.07884222093175669
# Test perplexity: 0
# Bashkir
# N= 225
# Epoch	Loss	Perplexity
# 1	0.097	0
# 2	0.084	0
# 3	0.0852	0
# Best epoch: 2, best valid loss: 0.08
# Test loss: 0.08553478982713487
# Test perplexity: 0
# Test loss: 0.07730336336441981
# Test perplexity: 0
# Test loss: 0.08630877176920573
# Test perplexity: 0
# Tatar
# N= 241
# Epoch	Loss	Perplexity
# 1	0.0892	0
# 2	0.0801	0
# 3	0.0749	0
# 4	0.0725	0
# 5	0.0668	0
# 6	0.0624	0
# 7	0.0605	0
# 8	0.0593	0
# 9	0.0568	0
# 10	0.0554	0
# 11	0.0574	0
# Best epoch: 10, best valid loss: 0.06
# Test loss: 0.05651016007815159
# Test perplexity: 0
# Test loss: 0.06094697039148325
# Test perplexity: 0
# Test loss: 0.07711367587330925
# Test perplexity: 0
# Sakha
# N= 207
# Epoch	Loss	Perplexity
# 1	0.1129	0
# 2	0.1159	0
# Best epoch: 1, best valid loss: 0.11
# Test loss: 0.08887827453981852
# Test perplexity: 0
# Test loss: 0.08114027837563677
# Test perplexity: 0
# Test loss: 0.08870571247045544
# Test perplexity: 0
# Chuvash
# N= 244
# Epoch	Loss	Perplexity
# 1	0.1093	0
# 2	0.1333	0
# Best epoch: 1, best valid loss: 0.11
# Test loss: 0.07890709794935633
# Test perplexity: 0
# Test loss: 0.07544547235932336
# Test perplexity: 0
# Test loss: 0.0803572799338669
# Test perplexity: 0
# Khalkha Mongolian
# N= 232
# Epoch	Loss	Perplexity
# 1	0.0918	0
# 2	0.0843	0
# 3	0.0828	0
# 4	0.0748	0
# 5	0.0835	0
# Best epoch: 4, best valid loss: 0.07
# Test loss: 0.10442212121240024
# Test perplexity: 0
# Test loss: 0.1393945852915446
# Test perplexity: 0
# Test loss: 0.11564081393439195
# Test perplexity: 0
# Buryat
# N= 311
# Epoch	Loss	Perplexity
# 1	0.0927	0
# 2	0.0826	0
# 3	0.0756	0
# 4	0.0736	0
# 5	0.0718	0
# 6	0.0685	0
# 7	0.0678	0
# 8	0.0724	0
# Best epoch: 7, best valid loss: 0.07
# Test loss: 0.05704165501609876
# Test perplexity: 0
# Test loss: 0.062407639082961194
# Test perplexity: 0
# Test loss: 0.05775881848534587
# Test perplexity: 0
# Kalmyk
# N= 231
# Epoch	Loss	Perplexity
# 1	0.0912	0
# 2	0.083	0
# 3	0.0787	0
# 4	0.0763	0
# 5	0.0745	0
# 6	0.0733	0
# 7	0.0723	0
# 8	0.0718	0
# 9	0.0708	0
# 10	0.0712	0
# Best epoch: 9, best valid loss: 0.07
# Test loss: 0.06389208995934689
# Test perplexity: 0
# Test loss: 0.06402745880186558
# Test perplexity: 0
# Test loss: 0.07241459532733603
# Test perplexity: 0
# Evenki
# N= 299
# Epoch	Loss	Perplexity
# 1	0.0798	0
# 2	0.0742	0
# 3	0.0726	0
# 4	0.0674	0
# 5	0.0644	0
# 6	0.0646	0
# Best epoch: 5, best valid loss: 0.06
# Test loss: 0.04565182617276807
# Test perplexity: 0
# Test loss: 0.04892952165572472
# Test perplexity: 0
# Test loss: 0.0578699538540282
# Test perplexity: 0
# Manchu
# N= 332
# Epoch	Loss	Perplexity
# 1	0.078	0
# 2	0.0707	0
# 3	0.0671	0
# 4	0.0644	0
# 5	0.0614	0
# 6	0.0598	0
# 7	0.0571	0
# 8	0.0562	0
# 9	0.054	0
# 10	0.0533	0
# 11	0.0526	0
# 12	0.054	0
# Best epoch: 11, best valid loss: 0.05
# Test loss: 0.045569420578968095
# Test perplexity: 0
# Test loss: 0.045247667365603976
# Test perplexity: 0
# Test loss: 0.06390138167932809
# Test perplexity: 0
# Nanai
# N= 223
# Epoch	Loss	Perplexity
# 1	0.121	0
# 2	0.114	0
# 3	0.1064	0
# 4	0.1059	0
# 5	0.1045	0
# 6	0.1047	0
# Best epoch: 5, best valid loss: 0.1
# Test loss: 0.08879013874071061
# Test perplexity: 0
# Test loss: 0.09903803557641545
# Test perplexity: 0
# Test loss: 0.09593562374200522
# Test perplexity: 0
# Ket
# N= 150
# Epoch	Loss	Perplexity
# 1	0.141	0
# 2	0.1327	0
# 3	0.1279	0
# 4	0.1242	0
# 5	0.1232	0
# 6	0.1245	0
# Best epoch: 5, best valid loss: 0.12
# Test loss: 0.07412001132965088
# Test perplexity: 0
# Test loss: 0.07567942142486572
# Test perplexity: 0
# Test loss: 0.07962331930796306
# Test perplexity: 0
# Northern Yukaghir
# N= 208
# Epoch	Loss	Perplexity
# 1	0.0904	0
# 2	0.0932	0
# Best epoch: 1, best valid loss: 0.09
# Test loss: 0.0691250551205415
# Test perplexity: 0
# Test loss: 0.05477701686322689
# Test perplexity: 0
# Test loss: 0.070058812888769
# Test perplexity: 0
# Southern Yukaghir
# N= 194
# Epoch	Loss	Perplexity
# 1	0.0998	0
# 2	0.0946	0
# 3	0.0919	0
# 4	0.0884	0
# 5	0.0872	0
# 6	0.0863	0
# 7	0.0872	0
# Best epoch: 6, best valid loss: 0.09
# Test loss: 0.06713519452773418
# Test perplexity: 0
# Test loss: 0.06310603207019719
# Test perplexity: 0
# Test loss: 0.07047763804799502
# Test perplexity: 0
# Itelmen
# N= 138
# Epoch	Loss	Perplexity
# 1	0.0617	0
# 2	0.0569	0
# 3	0.0544	0
# 4	0.0519	0
# 5	0.0509	0
# 6	0.0501	0
# 7	0.0494	0
# 8	0.0496	0
# Best epoch: 7, best valid loss: 0.05
# Test loss: 0.06753601976062941
# Test perplexity: 0
# Test loss: 0.06949482750646847
# Test perplexity: 0
# Test loss: 0.07019763666650523
# Test perplexity: 0
# Chukchi
# N= 288
# Epoch	Loss	Perplexity
# 1	0.0822	0
# 2	0.0763	0
# 3	0.0742	0
# 4	0.0724	0
# 5	0.0708	0
# 6	0.0685	0
# 7	0.0684	0
# 8	0.0672	0
# 9	0.0663	0
# 10	0.0663	0
# Best epoch: 9, best valid loss: 0.07
# Test loss: 0.05141228478815821
# Test perplexity: 0
# Test loss: 0.047730804413788075
# Test perplexity: 0
# Test loss: 0.06035235565569666
# Test perplexity: 0
# Nivkh
# N= 129
# Epoch	Loss	Perplexity
# 1	0.0756	0
# 2	0.0697	0
# 3	0.0631	0
# 4	0.0589	0
# 5	0.0569	0
# 6	0.056	0
# 7	0.0557	0
# 8	0.0569	0
# Best epoch: 7, best valid loss: 0.06
# Test loss: 0.06481082032817279
# Test perplexity: 0
# Test loss: 0.08485395880951278
# Test perplexity: 0
# Test loss: 0.07305330915968547
# Test perplexity: 0
# Hokkaido Ainu
# N= 197
# Epoch	Loss	Perplexity
# 1	0.1197	0
# 2	0.1124	0
# 3	0.1081	0
# 4	0.1034	0
# 5	0.1014	0
# 6	0.1098	0
# Best epoch: 5, best valid loss: 0.1
# Test loss: 0.11992833457017307
# Test perplexity: 0
# Test loss: 0.09691156859688915
# Test perplexity: 0
# Test loss: 0.1329355869196393
# Test perplexity: 0
# Korean
# N= 246
# Epoch	Loss	Perplexity
# 1	0.0762	0
# 2	0.0709	0
# 3	0.0702	0
# 4	0.0696	0
# 5	0.0688	0
# 6	0.0679	0
# 7	0.0673	0
# 8	0.0669	0
# 9	0.0671	0
# Best epoch: 8, best valid loss: 0.07
# Test loss: 0.12652300237640132
# Test perplexity: 0
# Test loss: 0.10414368356211802
# Test perplexity: 0
# Test loss: 0.13595019123418545
# Test perplexity: 0
# Japanese
# N= 260
# Epoch	Loss	Perplexity
# 1	0.072	0
# 2	0.0718	0
# 3	0.0661	0
# 4	0.0619	0
# 5	0.0603	0
# 6	0.0649	0
# Best epoch: 5, best valid loss: 0.06
# Test loss: 0.07969392308822044
# Test perplexity: 0
# Test loss: 0.0663710730960907
# Test perplexity: 0
# Test loss: 0.08632552715448233
# Test perplexity: 0
# Aleut
# N= 248
# Epoch	Loss	Perplexity
# 1	0.0752	0
# 2	0.0709	0
# 3	0.0685	0
# 4	0.0653	0
# 5	0.063	0
# 6	0.0614	0
# 7	0.0596	0
# 8	0.0582	0
# 9	0.0568	0
# 10	0.0555	0
# 11	0.0544	0
# 12	0.0537	0
# 13	0.0559	0
# Best epoch: 12, best valid loss: 0.05
# Test loss: 0.0512769861567405
# Test perplexity: 0
# Test loss: 0.05380800233303922
# Test perplexity: 0
# Test loss: 0.0699357174096569
# Test perplexity: 0
# Central Siberian Yupik
# N= 238
# Epoch	Loss	Perplexity
# 1	0.068	0
# 2	0.0629	0
# 3	0.0616	0
# 4	0.0578	0
# 5	0.0562	0
# 6	0.0558	0
# 7	0.0571	0
# Best epoch: 6, best valid loss: 0.06
# Test loss: 0.0487075212622891
# Test perplexity: 0
# Test loss: 0.04607765638036257
# Test perplexity: 0
# Test loss: 0.07365003804198834
# Test perplexity: 0
# Kalaallisut
# N= 274
# Epoch	Loss	Perplexity
# 1	0.0801	0
# 2	0.0763	0
# 3	0.0724	0
# 4	0.0715	0
# 5	0.0722	0
# Best epoch: 4, best valid loss: 0.07
# Test loss: 0.06836719756578877
# Test perplexity: 0
# Test loss: 0.06472870846127354
# Test perplexity: 0
# Test loss: 0.07401010937934374
# Test perplexity: 0
# Kannada
# N= 282
# Epoch	Loss	Perplexity
# 1	0.112	0
# 2	0.1045	0
# 3	0.0992	0
# 4	0.0964	0
# 5	0.096	0
# 6	0.0944	0
# 7	0.0948	0
# Best epoch: 6, best valid loss: 0.09
# Test loss: 0.07484083310932133
# Test perplexity: 0
# Test loss: 0.06873713591379557
# Test perplexity: 0
# Test loss: 0.07351428650795146
# Test perplexity: 0
# Malayalam
# N= 272
# Epoch	Loss	Perplexity
# 1	0.0621	0
# 2	0.0579	0
# 3	0.0557	0
# 4	0.0547	0
# 5	0.0517	0
# 6	0.0489	0
# 7	0.0485	0
# 8	0.0496	0
# Best epoch: 7, best valid loss: 0.05
# Test loss: 0.0646241158246994
# Test perplexity: 0
# Test loss: 0.05186643282800144
# Test perplexity: 0
# Test loss: 0.06946870903758441
# Test perplexity: 0
# Tamil
# N= 248
# Epoch	Loss	Perplexity
# 1	0.0664	0
# 2	0.0638	0
# 3	0.0618	0
# 4	0.0608	0
# 5	0.0593	0
# 6	0.058	0
# 7	0.0568	0
# 8	0.0565	0
# 9	0.0569	0
# Best epoch: 8, best valid loss: 0.06
# Test loss: 0.047062256163166415
# Test perplexity: 0
# Test loss: 0.049151695078345624
# Test perplexity: 0
# Test loss: 0.05414839954145493
# Test perplexity: 0
# Telugu
# N= 254
# Epoch	Loss	Perplexity
# 1	0.0963	0
# 2	0.091	0
# 3	0.0907	0
# 4	0.0909	0
# Best epoch: 3, best valid loss: 0.09
# Test loss: 0.08466562229817308
# Test perplexity: 0
# Test loss: 0.07863967900056339
# Test perplexity: 0
# Test loss: 0.08581784860355647
# Test perplexity: 0
# Burushaski
# N= 175
# Epoch	Loss	Perplexity
# 1	0.1222	0
# 2	0.1083	0
# 3	0.1072	0
# 4	0.1058	0
# 5	0.1053	0
# 6	0.106	0
# Best epoch: 5, best valid loss: 0.11
# Test loss: 0.129067747933524
# Test perplexity: 0
# Test loss: 0.11997694854276726
# Test perplexity: 0
# Test loss: 0.13564181327819824
# Test perplexity: 0
# Georgian
# N= 303
# Epoch	Loss	Perplexity
# 1	0.0942	0
# 2	0.0893	0
# 3	0.0877	0
# 4	0.0865	0
# 5	0.0857	0
# 6	0.0848	0
# 7	0.0849	0
# Best epoch: 6, best valid loss: 0.08
# Test loss: 0.06014225663918473
# Test perplexity: 0
# Test loss: 0.05295768225000405
# Test perplexity: 0
# Test loss: 0.06324742493456346
# Test perplexity: 0
# Basque
# N= 312
# Epoch	Loss	Perplexity
# 1	0.0967	0
# 2	0.0946	0
# 3	0.0962	0
# Best epoch: 2, best valid loss: 0.09
# Test loss: 0.07739036587568429
# Test perplexity: 0
# Test loss: 0.07248955486610183
# Test perplexity: 0
# Test loss: 0.07881180521769401
# Test perplexity: 0
# Abkhaz
# N= 256
# Epoch	Loss	Perplexity
# 1	0.0972	0
# 2	0.1061	0
# Best epoch: 1, best valid loss: 0.1
# Test loss: 0.08850919455289841
# Test perplexity: 0
# Test loss: 0.0830005999723095
# Test perplexity: 0
# Test loss: 0.08924766350537539
# Test perplexity: 0
# Adyghe
# N= 209
# Epoch	Loss	Perplexity
# 1	0.0736	0
# 2	0.0844	0
# Best epoch: 1, best valid loss: 0.07
# Test loss: 0.03904930598427805
# Test perplexity: 0
# Test loss: 0.031045521857470452
# Test perplexity: 0
# Test loss: 0.03950557640294709
# Test perplexity: 0
# Avar
# N= 227
# Epoch	Loss	Perplexity
# 1	0.0896	0
# 2	0.087	0
# 3	0.0842	0
# 4	0.0823	0
# 5	0.0838	0
# Best epoch: 4, best valid loss: 0.08
# Test loss: 0.07803168433353239
# Test perplexity: 0
# Test loss: 0.05439835326238112
# Test perplexity: 0
# Test loss: 0.08779916574251284
# Test perplexity: 0
# Tsez
# N= 216
# Epoch	Loss	Perplexity
# 1	0.0735	0
# 2	0.0708	0
# 3	0.0697	0
# 4	0.0702	0
# Best epoch: 3, best valid loss: 0.07
# Test loss: 0.07762182531533418
# Test perplexity: 0
# Test loss: 0.06110091882045043
# Test perplexity: 0
# Test loss: 0.07973479948661945
# Test perplexity: 0
# Lak
# N= 249
# Epoch	Loss	Perplexity
# 1	0.0659	0
# 2	0.0648	0
# 3	0.0619	0
# 4	0.0624	0
# Best epoch: 3, best valid loss: 0.06
# Test loss: 0.06969971398273146
# Test perplexity: 0
# Test loss: 0.061299819099016425
# Test perplexity: 0
# Test loss: 0.07370802149715194
# Test perplexity: 0
# Lezgian
# N= 201
# Epoch	Loss	Perplexity
# 1	0.0926	0
# 2	0.0877	0
# 3	0.0861	0
# 4	0.0848	0
# 5	0.0832	0
# 6	0.0814	0
# 7	0.0796	0
# 8	0.082	0
# Best epoch: 7, best valid loss: 0.08
# Test loss: 0.06523328693351936
# Test perplexity: 0
# Test loss: 0.062949685655402
# Test perplexity: 0
# Test loss: 0.06502708866821592
# Test perplexity: 0
# Dargwa
# N= 265
# Epoch	Loss	Perplexity
# 1	0.0576	0
# 2	0.0578	0
# Best epoch: 1, best valid loss: 0.06
# Test loss: 0.09510841639536732
# Test perplexity: 0
# Test loss: 0.07192699947281037
# Test perplexity: 0
# Test loss: 0.10231270340253722
# Test perplexity: 0
# Chechen
# N= 194
# Epoch	Loss	Perplexity
# 1	0.1256	0
# 2	0.1176	0
# 3	0.1161	0
# 4	0.1143	0
# 5	0.1116	0
# 6	0.1083	0
# 7	0.1089	0
# Best epoch: 6, best valid loss: 0.11
# Test loss: 0.09574376307811934
# Test perplexity: 0
# Test loss: 0.08087949283787461
# Test perplexity: 0
# Test loss: 0.09967324291307901
# Test perplexity: 0
# Standard Arabic
# N= 252
# Epoch	Loss	Perplexity
# 1	0.062	0
# 2	0.0566	0
# 3	0.0557	0
# 4	0.055	0
# 5	0.0556	0
# Best epoch: 4, best valid loss: 0.06
# Test loss: 0.052269993793396724
# Test perplexity: 0
# Test loss: 0.04885225976356352
# Test perplexity: 0
# Test loss: 0.05679099427329169
# Test perplexity: 0
# Modern Hebrew
# N= 250
# Epoch	Loss	Perplexity
# 1	0.0721	0
# 2	0.0682	0
# 3	0.0604	0
# 4	0.0609	0
# Best epoch: 3, best valid loss: 0.06
# Test loss: 0.061147049427032474
# Test perplexity: 0
# Test loss: 0.06244230345360138
# Test perplexity: 0
# Test loss: 0.06889882850646972
# Test perplexity: 0
# Mandarin Chinese
# N= 194
# Epoch	Loss	Perplexity
# 1	0.1375	0
# 2	0.1358	0
# 3	0.1419	0
# Best epoch: 2, best valid loss: 0.14
# Test loss: 0.10844707366117497
# Test perplexity: 0
# Test loss: 0.09243492229835137
# Test perplexity: 0
# Test loss: 0.11071036402712163
# Test perplexity: 0
